# %%
from pathlib import Path
from itertools import takewhile
import pandas as pd
from bz2 import decompress

# %%
p = Path('Al.rotated')

# %%
p.parts
# Out:
# ('Al.rotated',)

# %%
p.absolute()
# Out:
# PosixPath('/home/knoop/working/projects/python/pathlib/Al.rotated')

# %%
for pp in p.glob('rot_z_?'):
    print(pp)
# Out:
# Al.rotated/rot_z_9
# Al.rotated/rot_z_6
# Al.rotated/rot_z_3

# %%
paths = [pp for pp in p.glob('rot_z_?')]
paths.sort()

# %%
paths[0]/'aims.out.bz2'
# Out:
# PosixPath('Al.rotated/rot_z_3/aims.out.bz2')

# %%
# decompress
cfile = (paths[0]/'aims.out.bz2').read_bytes()
(paths[0]/'aims.out').write_text(decompress(cfile).decode())
# Out:
# 304177

# %%
with (paths[0]/'aims.out').open() as f:
    next(l for l in f if l.startswith('Convergence:'))
    print(f.readline())
# Out:
#   SCF    1 :  0.62E-01 |  0.64E+00 |  -0.12E+03 |  0.50E+00 |             . |        5.138 s |        5.141 s

# %%
with (paths[0]/'aims.out').open() as f:
    next(l for l in f if l.startswith('Convergence:'))
    # fancy for: pick lines until next empty one.
    lines = list(takewhile(lambda l: l.strip(), f))
    lines = [[float(r[i]) for i in (1, 3, 5, 7, 9)] for r in (l.split() for l in lines)]
    # print(lines)

# %%
df = pd.DataFrame(lines, columns='n q_app density eigen etot'.split()).set_index('n')

# %%
df
# Out:
#        q_app   density      eigen          etot
# n
# 1.0   0.0620  0.640000  -120.0000  5.000000e-01
# 2.0  -0.3600  0.620000 -1800.0000  5.400000e+00
# 3.0  -0.3900  0.150000  -110.0000  1.700000e-01
# 4.0  -0.4200  0.130000   -35.0000  1.200000e-01
# 5.0  -0.4400  0.096000    56.0000  6.800000e-02
# 6.0  -0.4500  0.037000    14.0000  2.600000e-02
# 7.0  -0.4400  0.033000    -4.6000  2.100000e-02
# 8.0  -0.4300  0.029000    -8.3000  6.700000e-03
# 9.0  -0.4100  0.025000    -2.8000  6.600000e-03
# 10.0 -0.3900  0.026000   -24.0000 -1.800000e-03
# 11.0 -0.3700  0.017000    -8.4000  2.600000e-03
# 12.0 -0.3500  0.016000    -9.7000  3.500000e-03
# 13.0 -0.3000  0.014000   -14.0000  3.800000e-03
# 14.0 -0.2400  0.011000   -18.0000  4.900000e-03
# 15.0 -0.2100  0.008100    -7.4000  1.300000e-03
# 16.0 -0.1700  0.006500    -6.7000  1.700000e-03
# 17.0 -0.1500  0.004500    -1.7000  2.900000e-04
# 18.0 -0.1300  0.003800    -1.7000  3.500000e-04
# 19.0 -0.1100  0.003000    -1.2000  4.800000e-04
# 20.0 -0.1000  0.002300    -0.2800  1.200000e-05
# 21.0 -0.0890  0.001900    -0.0330  1.900000e-05
# 22.0 -0.0810  0.001700    -0.0046  2.500000e-05
# 23.0 -0.0750  0.001500     0.1500 -4.600000e-05
# 24.0 -0.0620  0.001500     0.0330 -3.100000e-05
# 25.0 -0.0490  0.001300     0.0230 -5.000000e-05
# 26.0 -0.0350  0.001200    -0.0960 -3.400000e-05
# 27.0 -0.0220  0.001100    -0.2500 -9.100000e-06
# 28.0 -0.0110  0.000950    -0.2600  1.600000e-05
# 29.0  0.0055  0.000840    -0.3600  1.900000e-05
# 30.0  0.0240  0.000730    -0.3600  2.300000e-05
# 31.0  0.0340  0.000610    -0.1700  1.200000e-05
# 32.0  0.0420  0.000540    -0.1200  1.100000e-05
# 33.0  0.0500  0.000490    -0.0580  6.200000e-06
# 34.0  0.0570  0.000460    -0.0640  1.300000e-05
# 35.0  0.0640  0.000380    -0.0730  1.600000e-05
# 36.0  0.0700  0.000340    -0.0330  1.200000e-05
# 37.0  0.0740  0.000300    -0.0320  1.400000e-05
# 38.0  0.0780  0.000270    -0.0210  1.200000e-05
# 39.0  0.0820  0.000240     0.0087  1.300000e-05
# 40.0  0.0840  0.000210     0.0020  7.300000e-06
# 41.0  0.0850  0.000190     0.0210  4.600000e-06
# 42.0  0.0860  0.000170     0.0210  4.600000e-06
# 43.0  0.0870  0.000160     0.0420  6.300000e-06
# 44.0  0.0880  0.000150     0.0410  5.800000e-06
# 45.0  0.0890  0.000120     0.0490  6.700000e-06
# 46.0  0.0890  0.000097     0.0290  3.400000e-06
# 47.0  0.0890  0.000087     0.0190  3.000000e-06
# 48.0  0.0890  0.000079     0.0140  1.600000e-06
# 49.0  0.0890  0.000072     0.0170  2.300000e-06
# 50.0  0.0890  0.000065     0.0120  1.500000e-06
# 51.0  0.0880  0.000061     0.0190  1.900000e-06
# 52.0  0.0880  0.000052     0.0120  1.300000e-06
# 53.0  0.0880  0.000048     0.0092  7.500000e-07
# 54.0  0.0870  0.000045     0.0057  3.900000e-07
# 55.0  0.0870  0.000042     0.0070  1.400000e-07

# %%
# Delete uncompressed file
(paths[0] / 'aims.out').unlink()
