# %%
from scipy.fftpack import fft, dct, dst
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Number of sample points
N = 600

# %%
# sample spacing
dt = 1.0 / 800.0
T = N * dt

# %%
x = np.linspace(0.0, T, N)

# %%
w1 = 100
w2 = 250

# %%
# noise
rand = np.random.RandomState(0)

noise = rand.randn(len(x)) * 0.1

y = np.sin(w1 * 2.0*np.pi * x) + 0.5*np.sin(w2 * 2.0*np.pi * x) + noise

# %%
plt.plot(x, y)

# %%
yf = fft(y)

# %%
xf = np.linspace(0.0, 1.0/(2.0*dt), N//2)

# %%
#plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.plot(xf, abs(yf[:N//2]))

# %%
ys = dst(y)
yc = dct(y)

xc = np.linspace(0.0, 1.0/(2.0*dt), N)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, sharex=True, figsize=(10, 5))

ax1.plot(xc, yc)
ax2.plot(xc, ys)
