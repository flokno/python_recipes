# %%
from SALib.sample import sobol_sequence
import matplotlib.pyplot as plt
import numpy as np

# %%
nsamples = 200

# %%
qseq = sobol_sequence.sample(nsamples, 2)
qseq[:10, 0]
# Out:
# array([0.    , 0.5   , 0.75  , 0.25  , 0.375 , 0.875 , 0.625 , 0.125 ,
#        0.1875, 0.6875])

# %%
pseq = np.random.rand(nsamples, 2)
pseq[:10, 0]
# Out:
# array([0.30378223, 0.42267251, 0.58037797, 0.36245186, 0.52030648,
#        0.50759924, 0.7017151 , 0.38293544, 0.91102772, 0.20534148])

# %%
fig, axs = plt.subplots(ncols=2, sharey=True, 
                        subplot_kw={'aspect': 1}, 
                        figsize=(10, 10))
axs[0].plot(*qseq.T, '*')
axs[1].plot(*pseq.T, '*')
